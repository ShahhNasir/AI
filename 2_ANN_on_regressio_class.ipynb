# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
df = pd.read_pickle("/content/drive/MyDrive/Artificial_Intelligence_Engineering/AIA/2_CarPricesData.pkl")

# %%
df.head()
# Out:
#     Age     KM  Weight  HP  MetColor      CC  Doors  Price
# 0  23.0  46986  1165.0  90         1  2000.0      3  13500
# 1  23.0  72937  1165.0  90         1  2000.0      3  13750
# 2  24.0  41711  1165.0  90         1  2000.0      3  13950
# 3  26.0  48000  1165.0  90         0  2000.0      3  14950
# 4  30.0  38500  1170.0  90         0  2000.0      3  13750

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1435 entries, 0 to 1435
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1435 non-null   float64
#  1   KM        1435 non-null   int64
#  2   Weight    1435 non-null   float64
#  3   HP        1435 non-null   int64
#  4   MetColor  1435 non-null   int64
#  5   CC        1435 non-null   float64
#  6   Doors     1435 non-null   int64
#  7   Price     1435 non-null   int64
# dtypes: float64(3), int64(5)
# memory usage: 100.9 KB

# %%
len(df)
# Out:
# 1435

# %%
df
# Out:
#        Age     KM  Weight   HP  MetColor      CC  Doors  Price
# 0     23.0  46986  1165.0   90         1  2000.0      3  13500
# 1     23.0  72937  1165.0   90         1  2000.0      3  13750
# 2     24.0  41711  1165.0   90         1  2000.0      3  13950
# 3     26.0  48000  1165.0   90         0  2000.0      3  14950
# 4     30.0  38500  1170.0   90         0  2000.0      3  13750
# ...    ...    ...     ...  ...       ...     ...    ...    ...
# 1431  69.0  20544  1025.0   86         1  1300.0      3   7500
# 1432  72.0  19000  1015.0   86         0  1300.0      3  10845
# 1433  71.0  17016  1015.0   86         0  1300.0      3   8500
# 1434  70.0  16916  1015.0   86         1  1300.0      3   7250
# 1435  76.0      1  1114.0  110         0  1600.0      5   6950
#
# [1435 rows x 8 columns]

# %%
df.reset_index(drop="True",inplace=True)

# %%
df
# Out:
#        Age     KM  Weight   HP  MetColor      CC  Doors  Price
# 0     23.0  46986  1165.0   90         1  2000.0      3  13500
# 1     23.0  72937  1165.0   90         1  2000.0      3  13750
# 2     24.0  41711  1165.0   90         1  2000.0      3  13950
# 3     26.0  48000  1165.0   90         0  2000.0      3  14950
# 4     30.0  38500  1170.0   90         0  2000.0      3  13750
# ...    ...    ...     ...  ...       ...     ...    ...    ...
# 1430  69.0  20544  1025.0   86         1  1300.0      3   7500
# 1431  72.0  19000  1015.0   86         0  1300.0      3  10845
# 1432  71.0  17016  1015.0   86         0  1300.0      3   8500
# 1433  70.0  16916  1015.0   86         1  1300.0      3   7250
# 1434  76.0      1  1114.0  110         0  1600.0      5   6950
#
# [1435 rows x 8 columns]

# %%
X = df.iloc[:,:-1]
y = df['Price']

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[0.27848101, 0.19335471, 0.515625  , ..., 1.        , 1.        ,
#         0.33333333],
#        [0.27848101, 0.30014938, 0.515625  , ..., 1.        , 1.        ,
#         0.33333333],
#        [0.29113924, 0.1716468 , 0.515625  , ..., 1.        , 1.        ,
#         0.33333333],
#        ...,
#        [0.88607595, 0.07002086, 0.046875  , ..., 0.        , 0.        ,
#         0.33333333],
#        [0.87341772, 0.06960934, 0.046875  , ..., 1.        , 0.        ,
#         0.33333333],
#        [0.94936709, 0.        , 0.35625   , ..., 0.        , 0.42857143,
#         1.        ]])

# %%
pd.DataFrame(X,columns=df.columns[:-1])
# Out:
#            Age        KM    Weight        HP  MetColor        CC     Doors
# 0     0.278481  0.193355  0.515625  0.170732       1.0  1.000000  0.333333
# 1     0.278481  0.300149  0.515625  0.170732       1.0  1.000000  0.333333
# 2     0.291139  0.171647  0.515625  0.170732       1.0  1.000000  0.333333
# 3     0.316456  0.197528  0.515625  0.170732       0.0  1.000000  0.333333
# 4     0.367089  0.158433  0.531250  0.170732       0.0  1.000000  0.333333
# ...        ...       ...       ...       ...       ...       ...       ...
# 1430  0.860759  0.084539  0.078125  0.138211       1.0  0.000000  0.333333
# 1431  0.898734  0.078186  0.046875  0.138211       0.0  0.000000  0.333333
# 1432  0.886076  0.070021  0.046875  0.138211       0.0  0.000000  0.333333
# 1433  0.873418  0.069609  0.046875  0.138211       1.0  0.000000  0.333333
# 1434  0.949367  0.000000  0.356250  0.333333       0.0  0.428571  1.000000
#
# [1435 rows x 7 columns]

# %%
# Handling outliers
# Task

import seaborn as sns

sns.boxplot(x='Age',data=pd.DataFrame(X,columns=df.columns[:-1]))
# Out:
# <Axes: xlabel='Age'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1076, 7)
# (359, 7)
# (1076,)
# (359,)

# %%
print(y_train.dtype)
print(y_test.dtype)
# Out:
# int64
# int64

# %%
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
## Regression
# last layer should have one neuron
# and that one neuron should have linear activation function/No activation
# loss function is mean square error

## Binary class classification
# last layer should have one neuron
# that neuron should have sigmoid activation function
# Loss function is Binary Crossentropy

## Multiclass classification
# last layer should have no of neurons equal to no. of classes to be predicted
# and those neurons should have softmax activation function
# Loss function is Categorical crossentropy/Sparse categorical crossentropy

# %%
x_train.shape

# %%
# 1076/20 = 53.8
# 1 epoch means when all the data points has been used in training
# since we are sending 20 datapoints in one batch, it will require approx 54
# batches to exhuast all the training data points that means 1 epoch.

# %%
from tensorflow.keras.models import Sequential
from keras import Sequential

# %%
from keras import Sequential
from keras.layers import Dense

# %%
# Model building
from keras import Sequential
from keras.layers import Dense
import tensorflow as tf
from sklearn.metrics import r2_score

model = Sequential()
model.add(Dense(units=20,input_dim=7,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units = 32,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units=64,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units=1,kernel_initializer='he_uniform'))

model.compile(loss='mean_squared_error',optimizer='adam', metrics=[tf.keras.metrics.R2Score()])
model_history = model.fit(x_train,y_train,batch_size=32,epochs=100,verbose=1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 127725600.0000 - r2_score: -9.2391
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 127971280.0000 - r2_score: -9.1188
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126602776.0000 - r2_score: -9.9053
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 123804304.0000 - r2_score: -9.7189
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 127450144.0000 - r2_score: -8.4489
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 119881104.0000 - r2_score: -7.7395
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 106650656.0000 - r2_score: -7.3522
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 84222088.0000 - r2_score: -6.3549
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62806652.0000 - r2_score: -3.6501
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36512788.0000 - r2_score: -1.8781
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22717760.0000 - r2_score: -0.7025
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17100936.0000 - r2_score: -0.4019
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17702358.0000 - r2_score: -0.3201
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17234424.0000 - r2_score: -0.3472
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16019595.0000 - r2_score: -0.2760
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16613447.0000 - r2_score: -0.3053
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16344394.0000 - r2_score: -0.2572
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16534315.0000 - r2_score: -0.2892
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15379152.0000 - r2_score: -0.2075
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15382976.0000 - r2_score: -0.2050
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15529335.0000 - r2_score: -0.2303
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15077502.0000 - r2_score: -0.1420
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16741369.0000 - r2_score: -0.2532
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14562450.0000 - r2_score: -0.2372
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14523815.0000 - r2_score: -0.1552
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14428674.0000 - r2_score: -0.1223
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13163106.0000 - r2_score: -0.1653
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14789011.0000 - r2_score: -0.0566
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13934833.0000 - r2_score: -0.1074
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12531876.0000 - r2_score: -0.0100
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12945251.0000 - r2_score: -0.0940
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13325748.0000 - r2_score: -0.0094
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13172559.0000 - r2_score: -0.0573
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12307824.0000 - r2_score: 0.0159
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12759567.0000 - r2_score: 0.0433
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13314078.0000 - r2_score: 0.0788
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12084940.0000 - r2_score: 0.0686
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11998317.0000 - r2_score: 0.1315
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11596260.0000 - r2_score: 0.0868
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10092024.0000 - r2_score: 0.1915
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11067538.0000 - r2_score: 0.1394
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10864386.0000 - r2_score: 0.1741
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10771654.0000 - r2_score: 0.2083
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10017125.0000 - r2_score: 0.1987
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9834804.0000 - r2_score: 0.2354
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9558287.0000 - r2_score: 0.2547
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9333996.0000 - r2_score: 0.2330
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9405740.0000 - r2_score: 0.2735
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9069881.0000 - r2_score: 0.3001
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8237135.0000 - r2_score: 0.3092
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8633718.0000 - r2_score: 0.3465
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7728484.0000 - r2_score: 0.4017
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7883132.0000 - r2_score: 0.4109
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7701018.0000 - r2_score: 0.3719
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7540817.5000 - r2_score: 0.3539
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7309872.5000 - r2_score: 0.4313
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6785306.5000 - r2_score: 0.4961
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6603182.0000 - r2_score: 0.4866
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6404611.0000 - r2_score: 0.5412
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5771023.0000 - r2_score: 0.5037
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5765016.0000 - r2_score: 0.5449
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5874887.0000 - r2_score: 0.5671
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5327225.0000 - r2_score: 0.5926
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5662714.5000 - r2_score: 0.5918
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4757422.5000 - r2_score: 0.6481
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4630771.5000 - r2_score: 0.6265
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4318464.0000 - r2_score: 0.6463
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4222415.5000 - r2_score: 0.6734
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4143268.7500 - r2_score: 0.6988
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3898450.7500 - r2_score: 0.6761
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4030076.7500 - r2_score: 0.7081
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3424925.0000 - r2_score: 0.7177
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3211256.5000 - r2_score: 0.7284
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3445106.7500 - r2_score: 0.7478
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3363379.0000 - r2_score: 0.7482
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3011356.2500 - r2_score: 0.7583
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3005733.0000 - r2_score: 0.7727
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3207223.7500 - r2_score: 0.7629
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2732718.5000 - r2_score: 0.7631
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2474041.2500 - r2_score: 0.7960
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2541257.5000 - r2_score: 0.8054
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2365165.5000 - r2_score: 0.8084
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2507481.5000 - r2_score: 0.8008
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2749033.2500 - r2_score: 0.7613
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2462735.7500 - r2_score: 0.8182
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2390131.5000 - r2_score: 0.8174
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2013467.5000 - r2_score: 0.8374
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2000343.2500 - r2_score: 0.8539
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2124155.7500 - r2_score: 0.8375
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2459389.0000 - r2_score: 0.8020
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2062775.2500 - r2_score: 0.8406
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2309741.7500 - r2_score: 0.8343
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2182730.0000 - r2_score: 0.8330
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2098108.0000 - r2_score: 0.8268
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1980869.0000 - r2_score: 0.8426
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1835311.5000 - r2_score: 0.8483
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1751678.3750 - r2_score: 0.8662
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1793068.1250 - r2_score: 0.8673
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2177971.5000 - r2_score: 0.8083
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1909718.8750 - r2_score: 0.8298

# %%
# Do EDA and domain analysis
# Check if you have outliers
# Try other scaling option
# Increase the hidden layers
# Check for overfitting
# train for more epochs---- 100

# %%
model.evaluate(x_test,y_test)

# %%
df.columns
# Out:
# Index(['Age', 'KM', 'Weight', 'HP', 'MetColor', 'CC', 'Doors', 'Price'], dtype='object')

# %%
mylst = [10,74000,1200,85,1,1800,4]
np.array(mylst).reshape(1,-1)
# Out:
# array([[   10, 74000,  1200,    85,     1,  1800,     4]])

# %%
mylst = [20,74000,1200,85,1,1800,2]
scaled_value = sc.transform(np.array(mylst).reshape(1,-1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
scaled_value

# %%
predicted_price = model.predict(scaled_value)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
predicted_price
# Out:
# array([[16318.266]], dtype=float32)

# %% [markdown]
# Car data
# 7 feature 1 target(price)
# 1435 datapoints
# no null value, no categorical column
# reset index
# minmax scaler used to scale
# train test split
# createing a keras regression model with 4 layers
# trained model
# checked the performance
# new datapoint prediction
